# %%
import datetime as dt
import pandas as pd
from ggplot import *
# %matplotlib inline

# %%
data = {
    'Time Date': [dt.datetime(2015,6,24,2,55),
                  dt.datetime(2015,6,24,22,15),
                  dt.datetime(2015,6,26,0,38),
                  dt.datetime(2015,6,27,1,48),
                  dt.datetime(2015,6,27,23,5),
                  dt.datetime(2015,6,29,0,2),
                  dt.datetime(2015,6,30,1,41),
                  dt.datetime(2015,7,1,0,5),
                  dt.datetime(2015,7,1,21,48),
                  dt.datetime(2015,7,3,1,48),
                  dt.datetime(2015,7,4,0,18),
                  dt.datetime(2015,7,5,3,10),
                  dt.datetime(2015,7,5,23,38),
                  dt.datetime(2015,7,10,1,10),
                  dt.datetime(2015,7,11,2,40),
                  dt.datetime(2015,7,11,22,52)],
    'SRR': [33,
            25,
            21,
            32,
            31,
            26,
            28,
            23,
            25,
            24,
            21,
            21,
            23,
            None,
            None,
            18],
    'HR':  [88,
            120,
            100,
            92,
            108,
            104,
            84,
            96,
            108,
            104,
            80,
            88,
            92,
            None,
            88,
            80],
    'Skin Fold': [None,
                  None,
                  None,
                  None,
                  None,
                  None,
                  None,
                  None,
                  None,
                  None,
                  None,
                  None,
                  None,
                  3,
                  3,
                  2.5],
    'Notes': ['Skips beat ~8x/min',
              'HR while wide awake and now using stethoscope',
              'HR while resting. SRR irregular',
              'HR bit irregular',
              'HR bit irregular',
              '',
              'Did heavier exercise, but quickly exhausted by it.',
              'Same',
              '',
              '',
              '',
              'There seems to be less correlation between SRR and lethargy',
              '',
              'Could not take readings as was not sleeping',
              'Did not sleep. Still wet coughing',
              'Coughing mostly stopped. Is uncomfortable after meal\drink'],
    'Appetite': ['',
                 '',
                 '',
                 'Poor appetite.',
                 '',
                 '',
                 'Improved appetite',
                 '',
                 '',
                 'Worse appetite, particularly in the morning',
                 'Much better appetite',
                 '',
                 '',
                 'Acceptable (ate a full meal and drank a lot)',
                 'Improved. Eat and Drinks a lot',
                 'Eats full meals eventually'],
    'Lethargy': ['',
                 'Much less lethargic',
                 '',
                 'More lethargic',
                 'Marginally less lethargic.',
                 'Less lethargic',
                 '',
                 '',
                 'Marginally more lethargic',
                 'Much more lethargic',
                 'Less lethargic',
                 'Slightly more lethargic.',
                 'More lethargic',
                 'Very. (tries to sleep all day)',
                 'Marginally less lethargic',
                 'Same'],
}

df = pd.DataFrame(data)
df
# Out:
#                                         Appetite   HR  \
# 0                                                  88
# 1                                                 120
# 2                                                 100
# 3                                 Poor appetite.   92
# 4                                                 108
# 5                                                 104
# 6                              Improved appetite   84
# 7                                                  96
# 8                                                 108
# 9    Worse appetite, particularly in the morning  104
# 10                          Much better appetite   80
# 11                                                 88
# 12                                                 92
# 13  Acceptable (ate a full meal and drank a lot)  NaN
# 14                Improved. Eat and Drinks a lot   88
# 15                    Eats full meals eventually   80
#
#                           Lethargy  \
# 0
# 1              Much less lethargic
# 2
# 3                   More lethargic
# 4       Marginally less lethargic.
# 5                   Less lethargic
# 6
# 7
# 8        Marginally more lethargic
# 9              Much more lethargic
# 10                  Less lethargic
# 11        Slightly more lethargic.
# 12                  More lethargic
# 13  Very. (tries to sleep all day)
# 14       Marginally less lethargic
# 15                            Same
#
#                                                 Notes  SRR  Skin Fold  \
# 0                                  Skips beat ~8x/min   33        NaN
# 1       HR while wide awake and now using stethoscope   25        NaN
# 2                     HR while resting. SRR irregular   21        NaN
# 3                                    HR bit irregular   32        NaN
# 4                                    HR bit irregular   31        NaN
# 5                                                       26        NaN
# 6   Did heavier exercise, but quickly exhausted by...   28        NaN
# 7                                                Same   23        NaN
# 8                                                       25        NaN
# 9                                                       24        NaN
# 10                                                      21        NaN
# 11  There seems to be less correlation between SRR...   21        NaN
# 12                                                      23        NaN
# 13        Could not take readings as was not sleeping  NaN        3.0
# 14                  Did not sleep. Still wet coughing  NaN        3.0
# 15  Coughing mostly stopped. Is uncomfortable afte...   18        2.5
#
#              Time Date
# 0  2015-06-24 02:55:00
# 1  2015-06-24 22:15:00
# 2  2015-06-26 00:38:00
# 3  2015-06-27 01:48:00
# 4  2015-06-27 23:05:00
# 5  2015-06-29 00:02:00
# 6  2015-06-30 01:41:00
# 7  2015-07-01 00:05:00
# 8  2015-07-01 21:48:00
# 9  2015-07-03 01:48:00
# 10 2015-07-04 00:18:00
# 11 2015-07-05 03:10:00
# 12 2015-07-05 23:38:00
# 13 2015-07-10 01:10:00
# 14 2015-07-11 02:40:00
# 15 2015-07-11 22:52:00
#
# [16 rows x 7 columns]

# %%
print ggplot(df, aes(x='Time Date', y='SRR')) +\
    ggtitle('Sleeping Respiratory Rate against Time and Date') +\
    xlab('Time and Date') +\
    scale_y_continuous(name='SRR (Breaths/min)', limits=(0,40)) +\
    geom_line(aes(y='SRR'), color='blue') +\
    geom_point(aes(y='SRR'), color='blue') +\
    scale_x_date(labels=date_format('%a %b-%d'), breaks='1 day')
# Out:
# <ggplot: (23315109)>

# %%
print ggplot(df, aes(x='Time Date', y='HR')) +\
    ggtitle('Heart Rate against Time and Date') +\
    xlab('Time and Date') +\
    scale_y_continuous(name='HR (Beats/min)', limits=(0,150)) +\
    geom_line(aes(y='HR'), color='red') +\
    geom_point(aes(y='HR'), color='red') +\
    scale_x_date(labels=date_format('%a %b-%d'), breaks='1 day')
# Out:
# <ggplot: (3466381)>

# %%
print ggplot(df, aes(x='Time Date', y='Skin Fold')) +\
    ggtitle('Skin Fold restoration against Time and Date') +\
    xlab('Time and Date') +\
    scale_y_continuous(name='Skin Fold (Seconds to restore)', limits=(0,12)) +\
    geom_line(aes(y='Skin Fold'), color='green') +\
    geom_point(aes(y='Skin Fold'), color='green') +\
    scale_x_date(labels=date_format('%a %b-%d'), breaks='1 day')
# Out:
# <ggplot: (23104558)>
